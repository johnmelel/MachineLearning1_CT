# %% [markdown]
# # Notebook For Compressing Healthcare Data

# %%
import os
import findspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.types import StructType, StructField
import numpy as np
from rapidfuzz import fuzz
import sqlite3

# Ensure JAVA_HOME is set
#os.environ['JAVA_HOME'] = 'C:\Program Files\Java'  # Update this path to your Java installation

# Ensure SPARK_HOME is set
os.environ['SPARK_HOME'] = 'C:/Users/John/AppData/Local/Programs/Python/Python312/Lib/site-packages/pyspark'  # Update this path to your Spark installation

# Ensure HADOOP_HOME is set
#os.environ['HADOOP_HOME'] = 'C:/Hadoop'  # Update this path to your Hadoop installation

# Initialize findspark
findspark.init()

# %%
# Initialize SparkSession
spark = SparkSession.builder.master("local[*]") \
    .enableHiveSupport() \
    .config("spark.driver.memory", "4g") \
    .appName("Compress Healthcare Data") \
    .getOrCreate()

# %%
############## Helper Functions ################

def read_all_files_in_data_dir(directory):
    """
    Read in all parquet datasets in a directory and read them into a pyspark dataframe
    
    :return dict -> key:(filename): value (pyspark_data storing data)
    """
    dataframes_list = {}
    for entry in os.scandir(directory):  
        if entry.is_file() and entry.path.endswith('.parquet'):  # check if it's a parquet file
            file_path = entry.path
            # Read File into pyspark dataframe
            name_of_file = entry.path.split('/')[-1].split('.')[0]
            print(f"Reading File Path: {file_path}")
            df = spark.read.parquet(file_path)
            dataframes_list[name_of_file] = df
    print("SUCCESS: All Parquet Data in Data Directory Read")
    return dataframes_list

def print_schema_for_all_dataframes(dataframes_list):
    """
    Print Schema For All Dataframes in dataframe list and write out to file
    """
    with open('all_data_schemas.txt', 'w') as file:
        for df_key in dataframes_list.keys():
            df = dataframes_list[df_key]
            schema_string = df._jdf.schema().treeString()
            file.write(f"Schema for file: {df_key}\n")
            file.write(schema_string)
            file.write('\n----------------------------\n')

def convert_add_pyspark_df_to_pandas(dataframes_list):
    """
    Take list of pyspark dataframes, convert to pandas dataframes, convert to pickle file, and write to pandas_dataframes directory
    """
    for df_key in dataframes_list.keys():
        dataframes_list[df_key].write.mode('overwrite').parquet(f'parquet_files/{df_key}')
        # pandas_df = dataframes_list[df_key].toPandas()
        # pandas_df.to_pickle(f'pandas_dataframes/{df_key}.pkl')
    print("SUCCESS: All dataframes have been written as parquet files")


def load_dataframes_to_sql(dataframes_list, db_name='healthcare_data.db'):
    """
    Load all dataframes into a SQL database file.
    
    :param dataframes_list: dict -> key:(filename): value (pyspark_data storing data)
    :param db_name: str -> name of the database file
    """
    try:
        # Create a connection to the SQLite database
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()
        print(f"Connected to database {db_name}")
        
        for df_key in dataframes_list.keys():
            # Convert PySpark DataFrame to Pandas DataFrame
            pandas_df = dataframes_list[df_key].toPandas()
            
            # Load the DataFrame into the SQL database
            pandas_df.to_sql(df_key, conn, if_exists='replace', index=False)
            print(f"SUCCESS: {df_key} loaded into {db_name}")
        
        # Close the connection
        conn.close()
        print("SUCCESS: All dataframes have been loaded into the SQL database")
    
    except sqlite3.Error as e:
        print(f"SQLite error: {e}")
    except Exception as e:
        print(f"Error: {e}")

def load_dataframes_to_sql_in_chunks(dataframes_list, db_name='healthcare_data.db', chunk_size=10000):
    """
    Load all dataframes into a SQL database file in chunks to handle RAM constraints.
    
    :param dataframes_list: dict -> key:(filename): value (pyspark_data storing data)
    :param db_name: str -> name of the database file
    :param chunk_size: int -> number of rows per chunk
    """
    try:
        # Create a connection to the SQLite database
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()
        print(f"Connected to database {db_name}")
        
        for df_key in dataframes_list.keys():
            # Convert PySpark DataFrame to Pandas DataFrame in chunks
            df = dataframes_list[df_key]
            total_rows = df.count()
            num_chunks = total_rows // chunk_size + 1
            
            for i in range(num_chunks):
                pandas_df = df.limit(chunk_size).offset(i * chunk_size).toPandas()
                pandas_df.to_sql(df_key, conn, if_exists='append', index=False)
                print(f"SUCCESS: Chunk {i+1}/{num_chunks} of {df_key} loaded into {db_name}")
        
        # Close the connection
        conn.close()
        print("SUCCESS: All dataframes have been loaded into the SQL database in chunks")
    
    except sqlite3.Error as e:
        print(f"SQLite error: {e}")
    except Exception as e:
        print(f"Error: {e}")

# %%
dataframes_list = read_all_files_in_data_dir('../cleaned_data')
# Out:
# Reading File Path: ../cleaned_data\diagnoses_icd.parquet
# Reading File Path: ../cleaned_data\discharge.parquet
# Reading File Path: ../cleaned_data\discharge_detail.parquet
# Reading File Path: ../cleaned_data\drgcodes.parquet
# Reading File Path: ../cleaned_data\d_hcpcs.parquet
# Reading File Path: ../cleaned_data\d_icd_diagnoses.parquet
# Reading File Path: ../cleaned_data\d_icd_procedures.parquet
# Reading File Path: ../cleaned_data\d_labitems.parquet
# Reading File Path: ../cleaned_data\emar.parquet
# Reading File Path: ../cleaned_data\emar_detail.parquet
# Reading File Path: ../cleaned_data\hcpcsevents.parquet
# Reading File Path: ../cleaned_data\microbiologyevents.parquet
# Reading File Path: ../cleaned_data\omr.parquet
# Reading File Path: ../cleaned_data\patients.parquet
# Reading File Path: ../cleaned_data\pharmacy.parquet
# Reading File Path: ../cleaned_data\prescriptions.parquet
# Reading File Path: ../cleaned_data\procedures_icd.parquet
# Reading File Path: ../cleaned_data\radiology.parquet
# Reading File Path: ../cleaned_data\radiology_detail.parquet
# SUCCESS: All Parquet Data in Data Directory Read

# %%
print_schema_for_all_dataframes(dataframes_list)

# %%
load_dataframes_to_sql_in_chunks(dataframes_list)
# Out:
# Connected to database healthcare_data.db
# SUCCESS: Chunk 1/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 2/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 3/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 4/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 5/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 6/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 7/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 8/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 9/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 10/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 11/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 12/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 13/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 14/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 15/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 16/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 17/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 18/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 19/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 20/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 21/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 22/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 23/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 24/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 25/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 26/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 27/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 28/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 29/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 30/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 31/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 32/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 33/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 34/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 35/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 36/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 37/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 38/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 39/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 40/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 41/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 42/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 43/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 44/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 45/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 46/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 47/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 48/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 49/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 50/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 51/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 52/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 53/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 54/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 55/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 56/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 57/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 58/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 59/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 60/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 61/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 62/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 63/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 64/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 65/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 66/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 67/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 68/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 69/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 70/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 71/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 72/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 73/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 74/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 75/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 76/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 77/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 78/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 79/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 80/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 81/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 82/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 83/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 84/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 85/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 86/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 87/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 88/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 89/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 90/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 91/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 92/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 93/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 94/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 95/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 96/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 97/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 98/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 99/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 100/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 101/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 102/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 103/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 104/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 105/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 106/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 107/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 108/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 109/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 110/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 111/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 112/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 113/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 114/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 115/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 116/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 117/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 118/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 119/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 120/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 121/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 122/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 123/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 124/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 125/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 126/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 127/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 128/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 129/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 130/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 131/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 132/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 133/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 134/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 135/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 136/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 137/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 138/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 139/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 140/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 141/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 142/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 143/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 144/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 145/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 146/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 147/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 148/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 149/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 150/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 151/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 152/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 153/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 154/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 155/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 156/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 157/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 158/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 159/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 160/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 161/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 162/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 163/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 164/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 165/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 166/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 167/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 168/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 169/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 170/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 171/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 172/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 173/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 174/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 175/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 176/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 177/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 178/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 179/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 180/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 181/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 182/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 183/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 184/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 185/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 186/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 187/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 188/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 189/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 190/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 191/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 192/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 193/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 194/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 195/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 196/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 197/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 198/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 199/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 200/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 201/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 202/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 203/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 204/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 205/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 206/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 207/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 208/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 209/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 210/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 211/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 212/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 213/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 214/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 215/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 216/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 217/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 218/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 219/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 220/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 221/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 222/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 223/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 224/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 225/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 226/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 227/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 228/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 229/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 230/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 231/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 232/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 233/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 234/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 235/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 236/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 237/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 238/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 239/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 240/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 241/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 242/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 243/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 244/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 245/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 246/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 247/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 248/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 249/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 250/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 251/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 252/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 253/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 254/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 255/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 256/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 257/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 258/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 259/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 260/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 261/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 262/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 263/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 264/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 265/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 266/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 267/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 268/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 269/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 270/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 271/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 272/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 273/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 274/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 275/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 276/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 277/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 278/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 279/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 280/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 281/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 282/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 283/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 284/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 285/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 286/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 287/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 288/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 289/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 290/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 291/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 292/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 293/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 294/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 295/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 296/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 297/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 298/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 299/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 300/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 301/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 302/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 303/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 304/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 305/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 306/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 307/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 308/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 309/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 310/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 311/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 312/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 313/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 314/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 315/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 316/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 317/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 318/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 319/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 320/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 321/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 322/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 323/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 324/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 325/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 326/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 327/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 328/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 329/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 330/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 331/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 332/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 333/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 334/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 335/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 336/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 337/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 338/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 339/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 340/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 341/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 342/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 343/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 344/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 345/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 346/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 347/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 348/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 349/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 350/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 351/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 352/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 353/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 354/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 355/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 356/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 357/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 358/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 359/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 360/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 361/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 362/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 363/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 364/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 365/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 366/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 367/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 368/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 369/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 370/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 371/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 372/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 373/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 374/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 375/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 376/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 377/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 378/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 379/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 380/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 381/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 382/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 383/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 384/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 385/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 386/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 387/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 388/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 389/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 390/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 391/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 392/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 393/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 394/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 395/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 396/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 397/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 398/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 399/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 400/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 401/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 402/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 403/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 404/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 405/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 406/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 407/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 408/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 409/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 410/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 411/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 412/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 413/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 414/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 415/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 416/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 417/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 418/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 419/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 420/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 421/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 422/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 423/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 424/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 425/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 426/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 427/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 428/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 429/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 430/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 431/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 432/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 433/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 434/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 435/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 436/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 437/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 438/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 439/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 440/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 441/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 442/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 443/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 444/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 445/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 446/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 447/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 448/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 449/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 450/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 451/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 452/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 453/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 454/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 455/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 456/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 457/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 458/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 459/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 460/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 461/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 462/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 463/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 464/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 465/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 466/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 467/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 468/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 469/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 470/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 471/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 472/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 473/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 474/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 475/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 476/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 477/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 478/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 479/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 480/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 481/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 482/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 483/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 484/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 485/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 486/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 487/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 488/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 489/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 490/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 491/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 492/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 493/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 494/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 495/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 496/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 497/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 498/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 499/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 500/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 501/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 502/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 503/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 504/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 505/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 506/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 507/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 508/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 509/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 510/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 511/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 512/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 513/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 514/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 515/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 516/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 517/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 518/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 519/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 520/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 521/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 522/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 523/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 524/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 525/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 526/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 527/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 528/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 529/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 530/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 531/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 532/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 533/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 534/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 535/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 536/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 537/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 538/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 539/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 540/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 541/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 542/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 543/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 544/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 545/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 546/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 547/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 548/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 549/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 550/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 551/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 552/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 553/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 554/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 555/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 556/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 557/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 558/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 559/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 560/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 561/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 562/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 563/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 564/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 565/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 566/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 567/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 568/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 569/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 570/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 571/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 572/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 573/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 574/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 575/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 576/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 577/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 578/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 579/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 580/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 581/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 582/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 583/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 584/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 585/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 586/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 587/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 588/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 589/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 590/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 591/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 592/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 593/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 594/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 595/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 596/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 597/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 598/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 599/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 600/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 601/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 602/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 603/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 604/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 605/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 606/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 607/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 608/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 609/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 610/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 611/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 612/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 613/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 614/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 615/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 616/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 617/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 618/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 619/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 620/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 621/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 622/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 623/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 624/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 625/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 626/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 627/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 628/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 629/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 630/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 631/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 632/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 633/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 634/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 635/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 636/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# SUCCESS: Chunk 637/637 of cleaned_data\diagnoses_icd loaded into healthcare_data.db
# Error: An error occurred while calling o37.collectToPython.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 22 in stage 22.0 failed 1 times, most recent failure: Lost task 22.0 in stage 22.0 (TID 79) (10.0.0.89 executor driver): java.lang.OutOfMemoryError: GC overhead limit exceeded
# 	at org.apache.parquet.bytes.BytesInput$StreamBytesInput.toByteArray(BytesInput.java:285)
# 	at org.apache.parquet.bytes.BytesInput.toByteBuffer(BytesInput.java:237)
# 	at org.apache.parquet.bytes.BytesInput.toInputStream(BytesInput.java:246)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPageV1(VectorizedColumnReader.java:367)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.access$000(VectorizedColumnReader.java:49)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:272)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:268)
# 	at org.apache.parquet.column.page.DataPageV1.accept(DataPageV1.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPage(VectorizedColumnReader.java:268)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:186)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.SparkPlan.$anonfun$getByteArrayRdd$1(SparkPlan.scala:388)
# 	at org.apache.spark.sql.execution.SparkPlan$$Lambda$2474/0x00000007c0f47428.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsInternal$2(RDD.scala:893)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsInternal$2$adapted(RDD.scala:893)
# 	at org.apache.spark.rdd.RDD$$Lambda$2471/0x00000007c0f0e028.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:93)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.executor.Executor$TaskRunner$$Lambda$1538/0x00000007c0a20c28.apply(Unknown Source)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.failJobAndIndependentStages(DAGScheduler.scala:2856)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2(DAGScheduler.scala:2792)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2$adapted(DAGScheduler.scala:2791)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:2791)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1(DAGScheduler.scala:1247)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1$adapted(DAGScheduler.scala:1247)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:1247)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:3060)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2994)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2983)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:989)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2393)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2414)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2433)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2458)
# 	at org.apache.spark.rdd.RDD.$anonfun$collect$1(RDD.scala:1049)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:410)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:1048)
# 	at org.apache.spark.sql.execution.SparkPlan.executeCollect(SparkPlan.scala:448)
# 	at org.apache.spark.sql.Dataset.$anonfun$collectToPython$1(Dataset.scala:4149)
# 	at org.apache.spark.sql.Dataset.$anonfun$withAction$2(Dataset.scala:4323)
# 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:546)
# 	at org.apache.spark.sql.Dataset.$anonfun$withAction$1(Dataset.scala:4321)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$6(SQLExecution.scala:125)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:201)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$1(SQLExecution.scala:108)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:900)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:66)
# 	at org.apache.spark.sql.Dataset.withAction(Dataset.scala:4321)
# 	at org.apache.spark.sql.Dataset.collectToPython(Dataset.scala:4146)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: java.lang.OutOfMemoryError: GC overhead limit exceeded
# 	at org.apache.parquet.bytes.BytesInput$StreamBytesInput.toByteArray(BytesInput.java:285)
# 	at org.apache.parquet.bytes.BytesInput.toByteBuffer(BytesInput.java:237)
# 	at org.apache.parquet.bytes.BytesInput.toInputStream(BytesInput.java:246)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPageV1(VectorizedColumnReader.java:367)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.access$000(VectorizedColumnReader.java:49)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:272)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:268)
# 	at org.apache.parquet.column.page.DataPageV1.accept(DataPageV1.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPage(VectorizedColumnReader.java:268)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:186)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.SparkPlan.$anonfun$getByteArrayRdd$1(SparkPlan.scala:388)
# 	at org.apache.spark.sql.execution.SparkPlan$$Lambda$2474/0x00000007c0f47428.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsInternal$2(RDD.scala:893)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsInternal$2$adapted(RDD.scala:893)
# 	at org.apache.spark.rdd.RDD$$Lambda$2471/0x00000007c0f0e028.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:93)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.executor.Executor$TaskRunner$$Lambda$1538/0x00000007c0a20c28.apply(Unknown Source)

# %%
#convert_add_pyspark_df_to_pandas(dataframes_list)

# %%
spark.stop()

# %%
# Example on how to read the data

# import pandas as pd
# import pyarrow

# df = pd.read_parquet('parquet_files/d_hcpcs/')
# df.head()
